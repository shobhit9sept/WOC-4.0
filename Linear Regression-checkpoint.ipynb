# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
train = pd.read_csv(r"C:\Users\91892\Downloads\Linear_train.csv")
test = pd.read_csv(r"C:\Users\91892\Downloads\Linear_test.csv")

# %%
train
# Out:
#        Unnamed: 0          A            B          C          D          E  \
# 0               0  -9.989516  1564.957586   8.199060  32.508797  19.464400
# 1               1 -17.591800  1559.053039  12.302737 -36.351098   6.256406
# 2               2 -28.321695  1305.900952 -35.681049  -9.039358 -45.519426
# 3               3 -40.471241  1612.746996 -28.980454   2.137719 -34.767491
# 4               4 -36.525271  1852.275617 -32.744347  -1.439526 -14.061837
# ...           ...        ...          ...        ...        ...        ...
# 49995       49995  38.882059  1829.766795  -9.597762  42.286077 -45.676532
# 49996       49996 -29.570690  1467.757407  -2.581269   8.699766 -32.209400
# 49997       49997 -26.656483  1081.812179  19.742925 -49.109287  -8.179490
# 49998       49998  49.470595  1418.823031  14.854524  -6.995360  27.184947
# 49999       49999 -25.982072  1679.672351 -34.735487 -16.517472   6.606794
#
# ...

# %%
test
# Out:
#       Unnamed: 0          A            B          C          D          E  \
# 0              0  40.790740  1187.897579 -28.941991  43.498302  14.157983
# 1              1  47.968749  1498.588679  24.922821 -38.979082  16.405452
# 2              2   9.762564  1316.354415   1.170771  10.365178 -11.993156
# 3              3   6.414629  1895.586749  44.496934 -49.677800 -24.825833
# 4              4  -4.112012  1130.920162  19.103960  -8.741503 -28.589701
# ...          ...        ...          ...        ...        ...        ...
# 9995        9995 -37.802773  1204.712095  30.916166 -32.185868  -1.860028
# 9996        9996  21.841410  1067.350891  -9.598592  13.545191   2.910106
# 9997        9997 -34.734278  1630.673420  27.359399  -0.718695 -24.225154
# 9998        9998 -30.752354  1610.117693 -37.652326 -46.959112  18.151935
# 9999        9999  39.757972  1360.988948  -7.480509  27.155692  43.509194
#
#                 F          G          H            I  ...           L  \
# ...

# %%
train = train.drop(train.columns[0], axis = 1)
train
# Out:
#                A            B          C          D          E            F  \
# 0      -9.989516  1564.957586   8.199060  32.508797  19.464400  1644.524093
# 1     -17.591800  1559.053039  12.302737 -36.351098   6.256406  1640.834263
# 2     -28.321695  1305.900952 -35.681049  -9.039358 -45.519426  2039.003363
# 3     -40.471241  1612.746996 -28.980454   2.137719 -34.767491  2757.469393
# 4     -36.525271  1852.275617 -32.744347  -1.439526 -14.061837  2138.422485
# ...          ...          ...        ...        ...        ...          ...
# 49995  38.882059  1829.766795  -9.597762  42.286077 -45.676532  2340.446842
# 49996 -29.570690  1467.757407  -2.581269   8.699766 -32.209400  2065.685621
# 49997 -26.656483  1081.812179  19.742925 -49.109287  -8.179490  1755.112415
# 49998  49.470595  1418.823031  14.854524  -6.995360  27.184947  1235.231487
# 49999 -25.982072  1679.672351 -34.735487 -16.517472   6.606794  2375.299327
#
# ...

# %%
test = test.drop(test.columns[0], axis = 1)
test
# Out:
#               A            B          C          D          E            F  \
# 0     40.790740  1187.897579 -28.941991  43.498302  14.157983  2536.000797
# 1     47.968749  1498.588679  24.922821 -38.979082  16.405452  1798.950305
# 2      9.762564  1316.354415   1.170771  10.365178 -11.993156  2714.382200
# 3      6.414629  1895.586749  44.496934 -49.677800 -24.825833  2327.316373
# 4     -4.112012  1130.920162  19.103960  -8.741503 -28.589701  1299.418975
# ...         ...          ...        ...        ...        ...          ...
# 9995 -37.802773  1204.712095  30.916166 -32.185868  -1.860028  1515.265232
# 9996  21.841410  1067.350891  -9.598592  13.545191   2.910106  1286.431551
# 9997 -34.734278  1630.673420  27.359399  -0.718695 -24.225154  1309.956055
# 9998 -30.752354  1610.117693 -37.652326 -46.959112  18.151935  2489.587758
# 9999  39.757972  1360.988948  -7.480509  27.155692  43.509194  1700.776478
#
# ...

# %%
training_data = train.values
Y_train = training_data[:, -1].reshape(training_data.shape[0], 1)
X_train = training_data[:, :-1]
print("The shape of X_train is:", X_train.shape)
print("The shape of Y_train is:", Y_train.shape)
# Out:
# The shape of X_train is: (50000, 20)
# The shape of Y_train is: (50000, 1)

# %%
testing_data = test.values
Y_test = testing_data[:, -1].reshape(testing_data.shape[0], 1)
X_test = testing_data[:, :-1]
print("The shape of X_test is:", X_test.shape)
print("The shape of Y_test is:", Y_test.shape)
# Out:
# The shape of X_test is: (10000, 20)
# The shape of Y_test is: (10000, 1)

# %%
X_train_mean = X_train.mean(axis=0)
X_train_mean = np.hstack(X_train_mean)
X_train_std = X_train.std(axis=0)
X_train_std = np.hstack(X_train_std)

# %%
X_test_mean = X_test.mean(axis=0)
X_test_mean = np.hstack(X_test_mean)
X_test_std = X_test.std(axis=0)
X_test_std = np.hstack(X_test_std)

# %%
X_train_norm = (X_train - X_train_mean)/X_train_std
X_train_norm
# Out:
# array([[-0.34799407,  0.22031433,  0.28511282, ..., -0.15582334,
#          1.0052814 ,  1.00876462],
#        [-0.61114616,  0.19984917,  0.42713042, ...,  1.29439989,
#          0.44683234, -1.12340336],
#        [-0.98256011, -0.67757616, -1.23346387, ..., -0.20664643,
#          0.52015407, -1.18447479],
#        ...,
#        [-0.924919  , -1.45426802,  0.68461602, ...,  0.8468317 ,
#          0.41256961, -1.21414073],
#        [ 1.71021016, -0.28618815,  0.51544114, ..., -0.95334269,
#          1.31811777, -0.36359261],
#        [-0.90157434,  0.61791579, -1.20074042, ..., -1.63664414,
#         -0.1163058 , -1.67297842]])

# %%
X_test_norm = (X_test - X_train_mean)/X_train_std
X_test_norm
# Out:
# array([[ 1.40975807, -1.08657594, -1.00024254, ..., -0.6870117 ,
#         -0.19141266, -0.97090816],
#        [ 1.65822395, -0.00972035,  0.86387877, ...,  0.95560992,
#          0.74278028, -0.83440791],
#        [ 0.3357217 , -0.64134445,  0.04188196, ..., -1.5846549 ,
#         -1.71519115,  1.27084306],
#        ...,
#        [-1.20453086,  0.44808546,  0.94820239, ..., -0.24726467,
#         -0.87742582,  1.62852991],
#        [-1.06669707,  0.3768393 , -1.30168464, ...,  1.28587727,
#         -0.96740849, -0.63625988],
#        [ 1.37400893, -0.48664112, -0.25751637, ...,  1.31957967,
#         -0.0979464 , -1.33366307]])

# %%
Y_train_mean = Y_train.mean(axis=0)
Y_train_std = Y_train.std(axis=0)
Y_train_norm = (Y_train - Y_train_mean)/Y_train_std

# %%
Y_test_mean = Y_test.mean(axis=0)
Y_test_std = Y_test.std(axis=0)
Y_test_norm = (Y_test - Y_test_mean)/Y_test_std

# %%
X_train_norm = np.vstack((np.ones((X_train_norm.shape[0], )), X_train_norm.T)).T
X_train_norm
# Out:
# array([[ 1.        , -0.34799407,  0.22031433, ..., -0.15582334,
#          1.0052814 ,  1.00876462],
#        [ 1.        , -0.61114616,  0.19984917, ...,  1.29439989,
#          0.44683234, -1.12340336],
#        [ 1.        , -0.98256011, -0.67757616, ..., -0.20664643,
#          0.52015407, -1.18447479],
#        ...,
#        [ 1.        , -0.924919  , -1.45426802, ...,  0.8468317 ,
#          0.41256961, -1.21414073],
#        [ 1.        ,  1.71021016, -0.28618815, ..., -0.95334269,
#          1.31811777, -0.36359261],
#        [ 1.        , -0.90157434,  0.61791579, ..., -1.63664414,
#         -0.1163058 , -1.67297842]])

# %%
X_test_norm = np.vstack(((np.ones((X_test_norm.shape[0], )), X_test_norm.T))).T
X_test_norm
# Out:
# array([[ 1.        ,  1.40975807, -1.08657594, ..., -0.6870117 ,
#         -0.19141266, -0.97090816],
#        [ 1.        ,  1.65822395, -0.00972035, ...,  0.95560992,
#          0.74278028, -0.83440791],
#        [ 1.        ,  0.3357217 , -0.64134445, ..., -1.5846549 ,
#         -1.71519115,  1.27084306],
#        ...,
#        [ 1.        , -1.20453086,  0.44808546, ..., -0.24726467,
#         -0.87742582,  1.62852991],
#        [ 1.        , -1.06669707,  0.3768393 , ...,  1.28587727,
#         -0.96740849, -0.63625988],
#        [ 1.        ,  1.37400893, -0.48664112, ...,  1.31957967,
#         -0.0979464 , -1.33366307]])

# %%
def model(X, Y, learning_rate, iteration):
    m = Y_train.size
    theta = np.zeros((X_train_norm.shape[1], 1))
    for i in range(iteration):
        
        Y_pred = np.dot(X, theta)   # X@theta
        
        cost = (1/(2*m))*np.sum(np.square(Y_pred - Y_train))
        d_theta = (1/m)*np.dot(X_train_norm.T, Y_pred - Y_train)
        theta = theta - learning_rate*d_theta
        
        if(i%(iteration/10) == 0):
            print("The value of our cost is: ", cost)
    
        plt.scatter(i, cost)
            
    return theta, m

# %%
iteration = 3000
learning_rate = 0.009
theta, m = model(X_train_norm, Y_train, learning_rate, iteration)
# Out:
# The value of our cost is:  13398388.663990432
# The value of our cost is:  62158.99482955223
# The value of our cost is:  2180.609793164786
# The value of our cost is:  1908.3519698755626
# The value of our cost is:  1907.1044707211377
# The value of our cost is:  1907.0987008400573
# The value of our cost is:  1907.098673906449
# The value of our cost is:  1907.0986737795947
# The value of our cost is:  1907.0986737789922
# The value of our cost is:  1907.0986737789892

# %%
Y_pred = np.dot(X_test_norm, theta)
error = np.sqrt((1/(2*X_test_norm.shape[0]))*np.sum(np.square(Y_pred - Y_test)))

# %%
print("The test error is", error)
# Out:
# The test error is 1.2930773622275846
